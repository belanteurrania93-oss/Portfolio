# %%
name = input("what is your name?")
print("your name is",name)
print("please enter two numbers")
b = int(input())
a = int(input())
b += a
print("the sum of those two numbers is:",b)
number = int(input("please enter number"))
if number%2 == 0 :
   print("even")
else :
  print("odd")
# Out:
# your name is r
# please enter two numbers
# the sum of those two numbers is: 1
# even
